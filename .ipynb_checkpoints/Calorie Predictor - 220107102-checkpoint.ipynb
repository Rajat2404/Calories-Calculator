# %% [markdown]
# # **ML Model: Analysis of Daily Food & Nutrition**
#
#
# With the power of **data science and machine learning**, we can analyze daily food intake, track nutritional patterns, and even predict calorie consumption based on food composition.
#
# In this notebook, we embark on a journey to clean, explore, and model food nutrition data, revealing hidden patterns and making predictions that could help in personalized diet planning.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("/kaggle/input/daily-food-and-nutrition-dataset/daily_food_nutrition_dataset.csv")

# %%
display(df.head())
# Out:
#          Date  User_ID       Food_Item Category  Calories (kcal)  Protein (g)  \
# 0  2024-09-11      496            Eggs     Meat              173         42.4
# 1  2024-12-17      201           Apple   Fruits               66         39.2
# 2  2024-06-09      776  Chicken Breast     Meat              226         27.1
# 3  2024-08-27      112          Banana   Fruits              116         43.4
# 4  2024-07-28      622          Banana   Fruits              500         33.9
#
#    Carbohydrates (g)  Fat (g)  Fiber (g)  Sugars (g)  Sodium (mg)  \
# 0               83.7      1.5        1.5        12.7          752
# 1               13.8      3.2        2.6        12.2          680
# 2               79.1     25.8        3.2        44.7          295
# 3               47.1     16.1        6.5        44.1          307
# 4               75.8     47.0        7.8        19.4          358
#
#    Cholesterol (mg)  Meal_Type  Water_Intake (ml)
# 0               125      Lunch                478
# 1                97      Lunch                466
# 2               157  Breakfast                635
# 3                13      Snack                379
# 4               148      Lunch                471

# %% [markdown]
# # **01. Data Cleaning**

# %% [markdown]
# * Check for missing values
# * Drop rows with missing values
# * Check for duplicates
# * Convert 'Date' column to datetime
# * Remove outliers (Example: Calories above 3000 are considered outliers)

# %%
# Check for missing values
print("Missing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Date                 0
# User_ID              0
# Food_Item            0
# Category             0
# Calories (kcal)      0
# Protein (g)          0
# Carbohydrates (g)    0
# Fat (g)              0
# Fiber (g)            0
# Sugars (g)           0
# Sodium (mg)          0
# Cholesterol (mg)     0
# Meal_Type            0
# Water_Intake (ml)    0
# dtype: int64

# %%
# Drop rows with missing values
df.dropna(inplace=True)

# %%
# Check for duplicates
print(f'Number of duplicate rows: {df.duplicated().sum()}')
df.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %%
# Convert 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Remove outliers (Example: Calories above 3000 are considered outliers)
df = df[df['Calories (kcal)'] < 3000]

# %% [markdown]
# # **02. Exploratory Data Analysis (EDA)**

# %%
# Summary statistics
display(df.describe())
# Out:
#                              Date       User_ID  Calories (kcal)  \
# count                       10000  10000.000000     10000.000000
# mean   2024-07-01 02:49:37.920000    498.706300       327.693900
# min           2024-01-01 00:00:00      1.000000        50.000000
# 25%           2024-04-02 00:00:00    245.000000       190.000000
# 50%           2024-06-30 12:00:00    492.000000       328.000000
# 75%           2024-09-29 00:00:00    748.000000       464.000000
# max           2024-12-31 00:00:00   1000.000000       600.000000
# std                           NaN    289.123477       158.194716
#
#         Protein (g)  Carbohydrates (g)      Fat (g)     Fiber (g)  \
# count  10000.000000       10000.000000  10000.00000  10000.000000
# mean      25.523050          52.568550     25.43735      4.986940
# min        1.000000           5.000000      1.00000      0.000000
# 25%       13.200000          28.800000     13.30000      2.500000
# 50%       25.500000          52.800000     25.30000      5.000000
# 75%       37.700000          76.400000     37.60000      7.500000
# max       50.000000         100.000000     50.00000     10.000000
# std       14.131993          27.387152     14.14532      2.864984
#
#          Sugars (g)   Sodium (mg)  Cholesterol (mg)  Water_Intake (ml)
# count  10000.000000  10000.000000      10000.000000       10000.000000
# mean      25.052570    497.969000        151.886600         554.353600
# min        0.000000      0.000000          0.000000         100.000000
# 25%       12.500000    249.750000         76.000000         327.000000
# 50%       25.000000    495.000000        153.000000         555.500000
# 75%       37.700000    749.000000        228.000000         783.000000
# max       50.000000   1000.000000        300.000000        1000.000000
# std       14.480605    287.988001         87.360643         260.977642

# %%
plt.figure(figsize=(8, 5))
df.replace([np.inf, -np.inf], np.nan, inplace=True)
sns.histplot(df['Calories (kcal)'], bins=30, kde=True, color='blue')
plt.title('Distribution of Calories')
plt.xlabel('Calories (kcal)');plt.ylabel('Count')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_numeric = df.select_dtypes(include=['number'])

plt.figure(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Meal_Type', y='Calories (kcal)', data=df, palette='Set2')
plt.title('Calories by Meal Type')
plt.xlabel('Meal Type');plt.ylabel('Calories (kcal)')
plt.show()

# %% [markdown]
# # **03. Feature Engineering**
#
# * **Encoding Categories:** We converted meal types and food categories into machine-readable numbers.
# * **Scaling Features:** Nutritional values were standardized to ensure balanced learning.
# * **Splitting Data:** We divided our dataset into training and test sets to evaluate performance.

# %%
le = LabelEncoder()
df['Meal_Type'] = le.fit_transform(df['Meal_Type'])
df['Category'] = le.fit_transform(df['Category'])

X = df[['Protein (g)', 'Carbohydrates (g)', 'Fat (g)', 'Fiber (g)', 'Sugars (g)', 'Sodium (mg)', 'Cholesterol (mg)', 'Meal_Type', 'Category']]
y = df['Calories (kcal)']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # **04. Model Training**
#
# After training, our model learns to predict calorie counts based on protein, fat, carbohydrates, fiber, and sugars.

# %%
m = RandomForestRegressor(n_estimators=100, random_state=42)
m.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = m.predict(X_test)

# %% [markdown]
# # **05. Model Evaluation**
#
# * Mean Absolute Error (MAE): Measures how far off our predictions are.
# * Mean Squared Error (MSE): Captures overall prediction errors.
# * R-Squared Score: Tells us how well the model explains the variation in calorie intake.
# * And the cherry on top? A scatter plot comparing actual vs predicted calorie values, showing our model’s reliability.

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared Score: {r2:.2f}")
# Out:
# Mean Absolute Error: 139.53
# Mean Squared Error: 26094.63
# R-squared Score: -0.04

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.xlabel('Actual Calories')
plt.ylabel('Predicted Calories')
plt.title('Actual vs Predicted Calories')
plt.show()
